# %%
import numpy as np
import pandas as pd
import os
import xgboost as xgb

from sklearn.tree import DecisionTreeClassifier 
from sklearn.cross_validation import train_test_split

#记录程序运行时间
import time 
start_time = time.time()
# Out:
# /Users/Evan/anaconda3/lib/python3.5/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
os.chdir('/Users/Evan/Kaggle')

# %%
data_train = pd.read_csv('./Credit/data_train.csv')
data_test = pd.read_csv('./Credit/data_test.csv')

# %%
data_select_train = data_train.drop(['Unnamed: 0','timestamp_money','sum_total','mean_total','freq_total','sum_income','mean_income','freq_income','sum_spend','mean_spend','freq_spend'],axis = 1)
data_select_test = data_test.drop(['Unnamed: 0','timestamp_money','sum_total','mean_total','freq_total','sum_income','mean_income','freq_income','sum_spend','mean_spend','freq_spend'],axis = 1)

# %%
data_select_train.isnull().sum()/len(data_train)
# Out:
# ID                     0.000000
# gender                 0.000000
# career                 0.000000
# education              0.000000
# marriage               0.000000
# hukou                  0.000000
# Label                  0.000000
# bill_credit            0.119811
# credit_line            0.043564
# cash_advance           0.043564
# amount_transactions    0.043564
# browser1               0.148680
# browser2               0.148680
# browser3               0.148680
# browser4               0.148680
# browser5               0.148680
# browser6               0.148680
# browser7               0.148680
# browser8               0.148680
# browser9               0.148680
# browser10              0.148680
# browser11              0.148680
# dtype: float64

# %%
X = data_select_train.drop(['Label','ID'],axis =1)

# %%
y = data_select_train['Label']

# %%
data_select_test.columns
# Out:
# Index(['ID', 'gender', 'career', 'education', 'marriage', 'hukou', 'Label',
#        'bill_credit', 'credit_line', 'cash_advance', 'amount_transactions',
#        'browser1', 'browser2', 'browser3', 'browser4', 'browser5', 'browser6',
#        'browser7', 'browser8', 'browser9', 'browser10', 'browser11'],
#       dtype='object')

# %%
data_select_test = data_select_test.drop(['ID','Label'],axis =1)

# %% [markdown]
# ## 缺失值处理

# %%
X = X.fillna(-999)
y = y.fillna(-999)
data_select_test = data_select_test.fillna(-999)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.3,random_state=161214)

# %%
xgb_val = xgb.DMatrix(X_test,label=y_test,missing = -999)
xgb_train = xgb.DMatrix(X_train,label=y_train,missing = -999)
xgb_test = xgb.DMatrix(data_select_test,missing = -999)

# %%
params={
'booster':'gbtree',
'objective': 'multi:softmax', #多分类的问题
'num_class':10, # 类别数，与 multisoftmax 并用
'gamma':0.1,  # 用于控制是否后剪枝的参数,越大越保守，一般0.1、0.2这样子。
'max_depth':12, # 构建树的深度，越大越容易过拟合
'lambda':2,  # 控制模型复杂度的权重值的L2正则化项参数，参数越大，模型越不容易过拟合。
'subsample':0.7, # 随机采样训练样本
'colsample_bytree':0.7, # 生成树时进行的列采样
'min_child_weight':3, 
# 这个参数默认是 1，是每个叶子里面 h 的和至少是多少，对正负样本不均衡时的 0-1 分类而言
#，假设 h 在 0.01 附近，min_child_weight 为 1 意味着叶子节点中最少需要包含 100 个样本。
#这个参数非常影响结果，控制叶子节点中二阶导的和的最小值，该参数值越小，越容易 overfitting。 
'silent':1 ,#设置成1则没有运行信息输出，最好是设置为0.
'eta': 0.007, # 如同学习率
'seed':1000,
'nthread':7,# cpu 线程数
#'eval_metric': 'auc'
}
plst = list(params.items())
num_rounds = 5000 # 迭代次数
watchlist = [(xgb_train, 'train'),(xgb_val, 'val')]

#训练模型并保存
# early_stopping_rounds 当设置的迭代次数较大时，early_stopping_rounds 可在一定的迭代次数内准确率没有提升就停止训练
model = xgb.train(plst, xgb_train, num_rounds, watchlist,early_stopping_rounds=100)
model.save_model('./xgb.model') # 用于存储训练出的模型
print("best best_ntree_limit",model.best_ntree_limit)
# Out:
# [0]	train-merror:0.128453	val-merror:0.128665
# Multiple eval metrics have been passed: 'val-merror' will be used for early stopping.
#
# Will train until val-merror hasn't improved in 100 rounds.
# [1]	train-merror:0.127836	val-merror:0.128725
# [2]	train-merror:0.128273	val-merror:0.128545
# [3]	train-merror:0.127528	val-merror:0.128845
# [4]	train-merror:0.127348	val-merror:0.128965
# [5]	train-merror:0.127168	val-merror:0.128545
# [6]	train-merror:0.126988	val-merror:0.128665
# [7]	train-merror:0.127348	val-merror:0.128665
# [8]	train-merror:0.127219	val-merror:0.128545
# [9]	train-merror:0.127091	val-merror:0.128485
# [10]	train-merror:0.127194	val-merror:0.128605
# [11]	train-merror:0.127091	val-merror:0.128545
# [12]	train-merror:0.127245	val-merror:0.128485
# [13]	train-merror:0.127142	val-merror:0.128545
# [14]	train-merror:0.127219	val-merror:0.128425
# [15]	train-merror:0.127322	val-merror:0.128605
# [16]	train-merror:0.127708	val-merror:0.128425
# [17]	train-merror:0.12781	val-merror:0.128485
# [18]	train-merror:0.127605	val-merror:0.128365
# [19]	train-merror:0.127476	val-merror:0.128245
# [20]	train-merror:0.127528	val-merror:0.128245
# [21]	train-merror:0.127348	val-merror:0.128365
# [22]	train-merror:0.127579	val-merror:0.128185
# [23]	train-merror:0.127656	val-merror:0.128185
# [24]	train-merror:0.127528	val-merror:0.128365
# [25]	train-merror:0.127579	val-merror:0.128185
# [26]	train-merror:0.127579	val-merror:0.128125
# [27]	train-merror:0.127708	val-merror:0.128245
# [28]	train-merror:0.12781	val-merror:0.128185
# [29]	train-merror:0.127682	val-merror:0.128245
# [30]	train-merror:0.127759	val-merror:0.128305
# [31]	train-merror:0.127605	val-merror:0.128185
# [32]	train-merror:0.127708	val-merror:0.128125
# [33]	train-merror:0.127759	val-merror:0.128125
# [34]	train-merror:0.12781	val-merror:0.128185
# [35]	train-merror:0.127759	val-merror:0.128185
# [36]	train-merror:0.12781	val-merror:0.128185
# [37]	train-merror:0.12781	val-merror:0.128125
# [93]	train-merror:0.126217	val-merror:0.128305
# [94]	train-merror:0.126269	val-merror:0.128365
# [95]	train-merror:0.126243	val-merror:0.128365
# [96]	train-merror:0.126166	val-merror:0.128425
# [97]	train-merror:0.125986	val-merror:0.128485
# [98]	train-merror:0.12596	val-merror:0.128485
# [99]	train-merror:0.125858	val-merror:0.128485
# [100]	train-merror:0.125832	val-merror:0.128545
# [101]	train-merror:0.125703	val-merror:0.128485
# [102]	train-merror:0.125626	val-merror:0.128545
# [103]	train-merror:0.125678	val-merror:0.128545
# [104]	train-merror:0.125626	val-merror:0.128545
# [105]	train-merror:0.125549	val-merror:0.128545
# [106]	train-merror:0.125549	val-merror:0.128605
# [107]	train-merror:0.125472	val-merror:0.128605
# [108]	train-merror:0.125344	val-merror:0.128665
# [109]	train-merror:0.125369	val-merror:0.128545
# [110]	train-merror:0.125344	val-merror:0.128485
# [111]	train-merror:0.125292	val-merror:0.128425
# [112]	train-merror:0.125164	val-merror:0.128365
# [113]	train-merror:0.125138	val-merror:0.128365
# [114]	train-merror:0.125164	val-merror:0.128365
# [115]	train-merror:0.125035	val-merror:0.128305
# [116]	train-merror:0.124984	val-merror:0.128485
# [117]	train-merror:0.124907	val-merror:0.128425
# [118]	train-merror:0.124881	val-merror:0.128425
# [119]	train-merror:0.12483	val-merror:0.128425
# [120]	train-merror:0.124804	val-merror:0.128425
# [121]	train-merror:0.12483	val-merror:0.128365
# [122]	train-merror:0.12483	val-merror:0.128365
# [123]	train-merror:0.124778	val-merror:0.128425
# [124]	train-merror:0.124778	val-merror:0.128365
# [125]	train-merror:0.124727	val-merror:0.128425
# [126]	train-merror:0.124676	val-merror:0.128305
# [127]	train-merror:0.12465	val-merror:0.128305
# [128]	train-merror:0.12465	val-merror:0.128365
# [129]	train-merror:0.124599	val-merror:0.128425
# [130]	train-merror:0.124521	val-merror:0.128425
# [131]	train-merror:0.124444	val-merror:0.128485
# [132]	train-merror:0.124342	val-merror:0.128485
# [133]	train-merror:0.124342	val-merror:0.128485
# [134]	train-merror:0.124316	val-merror:0.128365
# [135]	train-merror:0.12429	val-merror:0.128365
# [136]	train-merror:0.124136	val-merror:0.128305
# [137]	train-merror:0.124162	val-merror:0.128305
# [138]	train-merror:0.124162	val-merror:0.128305
# Stopping. Best iteration:
# [38]	train-merror:0.12781	val-merror:0.128065
#
# best best_ntree_limit 39

# %%
preds = model.predict(xgb_test,ntree_limit=model.best_ntree_limit)

np.savetxt('xgb_submission.csv',np.c_[range(1,len(data_select_test)+1),preds],delimiter=',',header='ImageId,Label',comments='',fmt='%d')

#输出运行时长
cost_time = time.time()-start_time
print("xgboost success!",'\n',"cost time:",cost_time,"(s)......")
# Out:
# xgboost success!
#  cost time: 35.217331886291504 (s)......
